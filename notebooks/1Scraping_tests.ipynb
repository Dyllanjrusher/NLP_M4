# %%
from pyfuncs import scraper
from time import sleep
import selenium
from selenium.webdriver import Chrome
import numpy as np
from selenium.webdriver.common.action_chains import ActionChains
import re

# %%
Shopping = scraper.Google_Shopping_Scraper(product_name='guitar delay pedal', n_reviews=50, n_pages=2)

# %%
Shopping.get_all_pages()
# Out:
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# page 1 is done!
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# no more reviews on this page.
# page 2 is done!

# %%
import pandas as pd
df = pd.DataFrame(Shopping.all_reviews)
df.head(30)
# Out:
#                                               listing  ...              search
# 0   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 1   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 2   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 3   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 4   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 5   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 6   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 7   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 8   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 9   Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# 10  Behringer Vintage Delay VD400 Analog Delay Eff...  ...  guitar delay pedal
# ...

# %%
['test']*len(Shopping.all_reviews['listing'])
# Out:
# ['test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
# ...

# %%
cow = [1,2,4]
cow.extend([1,3,4])
cow
# Out:
# [1, 2, 4, 1, 3, 4]

# %%
result = Shopping.results[3]
test = Shopping.get_product_reviews(result)

# %%
test
# Out:
# []

# %%
splits = re.split("\n", test.text)

# %%
splits
# Out:
# ['April 7, 2020',
#  'the CLASSIC Bic.....(NO STRIKER GUARD) is THE best of ALL disposable lighters ever produced. Kept mine on a lighter leash attached to my purse from Oct.4, 2019 until its last strike in January 2020!! A-huh- mazing, replaced with another CLASSIC ',
#  'Andra · Review provided by walmart.com']

# %%
Shopping.a`ll_reviews['listing']
# Out:
# ['Zippo Butane Lighter Insert - Double Torch, Adult Unisex, Size: One size, Silver',
#  'Zippo Butane Lighter Insert - Double Torch, Adult Unisex, Size: One size, Silver',
#  'Zippo Butane Lighter Insert - Double Torch, Adult Unisex, Size: One size, Silver',
#  'Zippo Butane Lighter Insert - Double Torch, Adult Unisex, Size: One size, Silver',
#  'Zippo Butane Lighter Insert - Double Torch, Adult Unisex, Size: One size, Silver',
#  'Weber Lighter Cubes, Combustible - 24 cubes',
#  'Weber Lighter Cubes, Combustible - 24 cubes',
#  'Weber Lighter Cubes, Combustible - 24 cubes',
#  'Weber Lighter Cubes, Combustible - 24 cubes',
#  'Weber Lighter Cubes, Combustible - 24 cubes',
#  "Bic Lighters - 4 Each - Ray's Food Place- Talent - Delivered by Mercato",
#  "Bic Lighters - 4 Each - Ray's Food Place- Talent - Delivered by Mercato",
#  "Bic Lighters - 4 Each - Ray's Food Place- Talent - Delivered by Mercato",
#  "Bic Lighters - 4 Each - Ray's Food Place- Talent - Delivered by Mercato",
# ...

# %%
result.text
# Out:
# 'Loops & Threads Impeccable Yarn, Solid in Putty | 3 Pack | 4.5 oz | Michaels\n$3.49.\n$3.49Michaels Stores90% positive seller rating\n118 product reviews\nPopular for its feel, softness and workability, this yarn is available in a multitude of colors you will love. A wonderfully ...\nAcrylic · Medium Weight · Putty · 4.5 oz\nOther style options:  Cherry · Citron · Golden Beige · More'

# %%
reviews = Shopping.get_all_product_reviews_on_page()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-379-676ba83c42f9> in <module>
# ----> 1 reviews = Shopping.get_all_product_reviews_on_page()
#
# ~/Documents/NLP_M4/notebooks/pyfuncs/scraper.py in get_all_product_reviews_on_page(self)
#     128             price = self.results[prod].find_element_by_css_selector('span').text.split('.\n')[0]
#     129             link = self.results[prod].find_element_by_css_selector('div .IHk3ob > a').get_attribute('href')
# --> 130             reviews = self.get_product_reviews(self.results[prod])
#     131             #extend all_reviews only if we were able to get reviews to begin with
#     132             if reviews:
#
# ~/Documents/NLP_M4/notebooks/pyfuncs/scraper.py in get_product_reviews(self, result, n_reviews)
#      68             return None
#      69         #click on all reviews
# ...

# %%
Shopping.all_reviews['listing']
# Out:
# ['Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Caron Simply Soft Yarn - Black',
#  'Caron Simply Soft Yarn - Black',
#  'Caron Simply Soft Yarn - Black',
#  'Caron Simply Soft Yarn - Black',
#  'Caron Simply Soft Yarn - Black',
#  'Lion Brand Mandala Yarn Cake - Griffin',
#  'Lion Brand Mandala Yarn Cake - Griffin',
#  'Lion Brand Mandala Yarn Cake - Griffin',
#  'Lion Brand Mandala Yarn Cake - Griffin',
#  'Lion Brand Mandala Yarn Cake - Griffin',
#  'Bernat Blanket 10.5oz Yarn | Plum Fields | 10.5 oz | 100% Polyester',
#  'Bernat Blanket 10.5oz Yarn | Plum Fields | 10.5 oz | 100% Polyester',
# ...

# %%
all_reviews = Shopping.get_all_pages()
# Out:
# page 1 is done!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/Documents/NLP_M4/notebooks/pyfuncs/scraper.py in get_all_pages(self, num_pages)
#     152                 #do scan
# --> 153                     self.get_all_product_reviews_on_page()
#     154                 except Exception as e:
#
# ~/Documents/NLP_M4/notebooks/pyfuncs/scraper.py in get_all_product_reviews_on_page(self)
#     125             self.get_results()
# --> 126             listing = self.results[prod].find_element_by_css_selector('h3').text
#     127             price = self.results[prod].find_element_by_css_selector('span').text.split('.\n')[0]
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-368-b7081496900d> in <module>
# ...

# %%
Shopping.all_reviews['listing'][-1]
# Out:
# 'Cotton Kings - Twirls Color Changing Cake Yarn (Color: Aquamarine)'

# %%
all_reviews['listing']
# Out:
# ['Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Red Heart Super Saver Economy Size Yarn | Cherry Red | 7 oz | 100% Acrylic',
#  'Caron Simply Soft Yarn - Black',
#  'Caron Simply Soft Yarn - Black',
#  'Caron Simply Soft Yarn - Black',
#  'Caron Simply Soft Yarn - Black',
#  'Caron Simply Soft Yarn - Black',
#  'Lion Brand Mandala DK Acrylic Yarn Knitting Yarn Multi/Griffin',
#  'Lion Brand Mandala DK Acrylic Yarn Knitting Yarn Multi/Griffin',
#  'Lion Brand Mandala DK Acrylic Yarn Knitting Yarn Multi/Griffin',
#  'Lion Brand Mandala DK Acrylic Yarn Knitting Yarn Multi/Griffin',
#  'Lion Brand Mandala DK Acrylic Yarn Knitting Yarn Multi/Griffin',
# ...

# %%
num = 0
def divide(num):
    try:
        return num/0
    except:
        print('uhuh')
try:
    divide(num)
except:
    print('nuuh')
# Out:
# uhuh

# %%
result.find_element_by_css_selector(' a > span:nth-of-type(2)').text
# Out:
# '128 product reviews'

# %%
result.find_element_by_css_selector('a > span').get_attribute('innerHTML')
# Out:
# '<span class="Rv6wm">97%</span> positive'

# %%
all_reviews = Shopping.get_product_reviews(result)

# %%
all_reviews = Shopping.get_all_product_reviews_on_page()

# %%
all_reviews['listing']
# Out:
# ['Brunswick TZone Patriot Blaze Bowling Ball | Bowling.Com',
#  'Brunswick TZone Patriot Blaze Bowling Ball | Bowling.Com',
#  'Brunswick TZone Patriot Blaze Bowling Ball | Bowling.Com',
#  'Brunswick TZone Patriot Blaze Bowling Ball | Bowling.Com',
#  'Brunswick TZone Patriot Blaze Bowling Ball | Bowling.Com',
#  'Storm Ice Storm Blue White Bowling Ball',
#  'Storm Ice Storm Blue White Bowling Ball',
#  'Storm Ice Storm Blue White Bowling Ball',
#  'Storm Ice Storm Blue White Bowling Ball',
#  'Storm Ice Storm Blue White Bowling Ball',
#  'Ebonite Maxim Captain Midnight Bowling Ball',
#  'Ebonite Maxim Captain Midnight Bowling Ball',
#  'Ebonite Maxim Captain Midnight Bowling Ball',
#  'Ebonite Maxim Captain Midnight Bowling Ball',
#  'Ebonite Maxim Captain Midnight Bowling Ball',
#  'KR Strikeforce Clear Red Rose Ball Bowling Ball | Bowling.Com',
#  'KR Strikeforce Clear Red Rose Ball Bowling Ball | Bowling.Com',
#  'KR Strikeforce Clear Red Rose Ball Bowling Ball | Bowling.Com',
# ...

# %%
result = Shopping.results[15]
link = 'https://www.google.com/aclk?sa=L&ai=DChcSEwjYseGAtY7rAhWy7LUKHWd4COIYABAFGgJxbg&sig=AOD64_0KrRl_E-In-fC_8yDGX-xG9jSp2A&ctype=46&q=&ved=0ahUKEwi51N2AtY7rAhUzZDUKHZCIDhUQ2CkIugQ&adurl='

# %%
result.find_element_by_css_selector('div .IHk3ob > a').get_attribute('href')
# Out:
# 'https://www.google.com/aclk?sa=L&ai=DChcSEwjYseGAtY7rAhWy7LUKHWd4COIYABAuGgJxbg&sig=AOD64_3V3F-UVjMuPgSe6yNOXwGMjzz7cw&ctype=5&q=&ved=0ahUKEwi51N2AtY7rAhUzZDUKHZCIDhUQg-UECPoG&adurl='

# %%
listing = result.find_element_by_css_selector('h3')
price = result.find_element_by_css_selector('span').text.split('.\n')[0]
link = result.find_element_by_css_selector('div .IHk3ob > a').get_attribute('href')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-218-e64c82c328c5> in <module>
#       1 listing = result.find_element_by_css_selector('h3')
#       2 price = result.find_element_by_css_selector('span').text.split('.\n')[0]
# ----> 3 link = self.driver.find_element_by_css_selector('')
#
# NameError: name 'self' is not defined

# %%
all_reviews = Shopping.get_all_product_reviews_on_page()
# Out:
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah
# blah

# %%
len(all_reviews)
for rev in all_reviews:
    print(rev)
# Out:
# ["Poor product and equally poor customer service. Purchased my MS170 with warranties from Stihl and Northern Tools. Reviewed the owners manual, filled it with Stihl fuel and filled the bar oil chamber. Took about ten pulls to start which was the first indication of a problem. Finally, it started but would immediately died after a load was placed on the unit. I assumed it was the new gremlins in the unit but then it completely died after less than 5 minutes of operation. Returned the unit to Northern Tools assuming they would fix the issue under warranty,but told me it was neglect on my part. This is not my first chainsaw or first time cutting trees since I've been doing this for 20 years, Totally lost fail in Northern Tools and Stihl since it feels like the warrant is just a gimmick and I sincerely feel they sold me a unit with a clutch that was seized or over torqued from the factor.... heck the hard start, dying under a load and seizing up. I recommend not getting the warranties an
# ...

# %%
result = Shopping.results[0]
driver = Shopping.get_product_reviews(result)

# %%
from collections import defaultdict
test_dict = defaultdict(list)
bl = [1,23,5,6,6]

# %%
test_dict['listing'].extend(bl)

# %%
test_dict['listing'][0]
# Out:
# 1

# %%
results = Shopping.results[1]
driver = Shopping.get_product_reviews(result)
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-110-fe3e7de30bd3> in <module>
#       1 results = Shopping.results[1]
# ----> 2 driver = Shopping.get_product_reviews(result)
#
# ~/Documents/NLP_M4/notebooks/pyfuncs/scraper.py in get_product_reviews(self, result, n_reviews)
#      59         Will implement scraping on multiple pages later."""
#      60         # for listing in self.results:
# ---> 61         result.find_element_by_css_selector(' a > span:nth-of-type(2)').click()
#      62         #click on all reviews
#      63         self.driver.find_element_by_css_selector("section#reviews > div:nth-of-type(2) > div > a").click()
#
# ~/anaconda3/envs/metis/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_css_selector(self, css_selector)
#     428             element = element.find_element_by_css_selector('#foo')
# ...

# %%
Shopping.driver.find_element_by_css_selector('[aria-label="Page 2"]').text
# Out:
# '2'

# %%
num_pages = 3
for page in range(num_pages ):
    if page+1  == 1:
        #do first scan
        
    else:
        try:
        #click on page n
            self.driver.find_element_by_css_selector(f'[aria-label="Page {page+1}"]').click
        #do scan
        except:
            print('no more pages')
# Out:
# 0

# %%
all_reviews
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-322-6fd67161b91c> in <module>
# ----> 1 all_reviews.extend(all_reviews)
#
# AttributeError: 'collections.defaultdict' object has no attribute 'extend'

# %%
reviews = []
for result in Shopping.results:
    reviews.append(Shopping.get_product_reviews(result))
